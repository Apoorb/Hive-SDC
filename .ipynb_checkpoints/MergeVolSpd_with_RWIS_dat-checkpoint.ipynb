# %% [markdown]
# # Merge the Volume and Speed Data with the Weather Data

# %% [markdown]
#     Created by: Apoorba Bibeka
#     Date: 04/12/2019

# %%
import boto3 #Need to read and write files to aws s3 bucket
import pandas as pd
from io import BytesIO as StringIO 
import numpy as np

# %% [markdown]
# ## Load the RWIS ATMOS Weather Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018HiveRWIS_AtosDat.csv')
RWISdat=pd.read_csv(obj['Body'])
RWISdat.head()
# Out:
#    rwisid  avgairtemp  avgwindspd  avgwindgust  avgwinddir setwinddir  \
# 0    1354        16.5        11.0         17.0       250.0  ["W","W"]
# 1    1354        16.0         9.0         12.0       254.0  ["W","W"]
# 2    1354        15.3         6.0         10.0       260.0  ["W","W"]
# 3    1354        14.7         6.0          9.0       261.0  ["W","W"]
# 4    1354        14.5         7.0          9.0       256.0  ["W","W"]
#
#           setprecpints  avgprecprt  avgprecpaccm  avgvisft      setprecptyp  \
# 0      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 1      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 2      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 3      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 4  ["Slight","Slight"]         0.0      -99999.0    6560.0  ["Snow","Snow"]
#
#                 time5m
# 0  2018-02-01 00:00:00
# 1  2018-02-01 00:05:00
# 2  2018-02-01 00:10:00
# 3  2018-02-01 00:15:00
# 4  2018-02-01 00:20:00

# %% [markdown]
# ## Load RWIS Surface Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018HiveRWIS_SurfDat.csv')
Surfdat=pd.read_csv(obj['Body'])
Surfdat.head()
# Out:
#    rwisid  avgchempct                          setsurfstat  \
# 0    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 1    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 2    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 3    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 4    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
#
#                 time5m
# 0  2018-02-01 00:00:00
# 1  2018-02-01 00:05:00
# 2  2018-02-01 00:10:00
# 3  2018-02-01 00:15:00
# 4  2018-02-01 00:20:00

# %%
RWISdat1=pd.merge(RWISdat,Surfdat,on=['rwisid','time5m'],how='outer')

# %% [markdown]
# ## Load the Volume Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018ProcessVolDatClass.csv')
VolDat=pd.read_csv(obj['Body'])
VolDat=VolDat.drop(columns='Unnamed: 0')
VolDat.head()
# Out:
#    deviceId             DateTime  AvgSpdClass0  AvgSpdClass1  AvgSpdClass2  \
# 0       384  2018-02-01 00:05:00           0.0     65.650002     60.340000
# 1       384  2018-02-01 00:10:00           0.0      0.000000     63.280001
# 2       384  2018-02-01 00:15:00           0.0     70.397497     65.567501
# 3       384  2018-02-01 00:20:00           0.0      0.000000     64.876668
# 4       384  2018-02-01 00:25:00           0.0     68.420002      0.000000
#
#    AvgSpdClass3  VolClass0  VolClass1  VolClass2  VolClass3     SITENAME  \
# 0     62.452963          0          2          2         16  Summit East
# 1     60.666666          0          0          2          7  Summit East
# 2     60.180500          0          3          3         11  Summit East
# 3     62.102500          0          0          4         13  Summit East
# 4     59.529167          0          2          0          8  Summit East
#
#    Milepost Direction  TotVeh  PerHGV
# 0     325.8        WB      20   80.00
# 1     325.8        WB       9   77.78
# 2     325.8        WB      17   64.71
# 3     325.8        WB      17   76.47
# 4     325.8        WB      10   80.00

# %%
VolDat.columns
# Out:
# Index([u'deviceId', u'DateTime', u'AvgSpdClass0', u'AvgSpdClass1',
#        u'AvgSpdClass2', u'AvgSpdClass3', u'VolClass0', u'VolClass1',
#        u'VolClass2', u'VolClass3', u'SITENAME', u'Milepost', u'Direction',
#        u'TotVeh', u'PerHGV'],
#       dtype='object')

# %% [markdown]
# ## Load the mapping table for Backup Weather Station and speed sensor station

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/SecndRWIS_SpdID_Map.csv')
SecKeyMap=pd.read_csv(obj['Body'])
SecKeyMap.head()
# Out:
#    SecStat  backup_rwis
# 0      383           36
# 1      393         3422
# 2      394           36
# 3      395           36
# 4      396           36

# %% [markdown]
# ## Load the mapping table for Primary Weather Station and speed sensor station

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/PrimRWIS_SpdID_Map.csv')
PrimKeyMap=pd.read_csv(obj['Body'])
PrimKeyMap.head()
# Out:
#    PrimStat  nearest_rwis
# 0       383          1354
# 1       393            36
# 2       394          1354
# 3       395          1354
# 4       396          1354

# %%
# Get index for time 
RWISdat1['DateTime']=pd.to_datetime(RWISdat1['time5m'],format='%Y-%m-%d %H:%M:%S')
dev=RWISdat1.rwisid.unique().tolist()
RWISdat1=RWISdat1.rename(str,columns={'rwisid':'RWISid'})
# Set index
RWISdat1=RWISdat1.set_index(['RWISid','DateTime']) 
# Create time interval index without missing values
index = pd.date_range('2018-02-01','2018-02-28',closed='right',freq='5min')
# Create a multiindex
multi_index=pd.MultiIndex.from_product([dev,index],names=['RWISid','DateTime'])
# Reindex. Now the missing values have nan. 
RWISdat1=RWISdat1.reindex(multi_index)
RWISdat1=RWISdat1.reset_index()

# %%
RWISdat1.head()
# Out:
#    RWISid            DateTime  avgairtemp  avgwindspd  avgwindgust  \
# 0    1354 2018-02-01 00:05:00        16.0         9.0         12.0
# 1    1354 2018-02-01 00:10:00        15.3         6.0         10.0
# 2    1354 2018-02-01 00:15:00        14.7         6.0          9.0
# 3    1354 2018-02-01 00:20:00        14.5         7.0          9.0
# 4    1354 2018-02-01 00:25:00        14.4         6.0          9.0
#
#    avgwinddir setwinddir         setprecpints  avgprecprt  avgprecpaccm  \
# 0       254.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 1       260.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 2       261.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 3       256.0  ["W","W"]  ["Slight","Slight"]         0.0      -99999.0
# 4       250.0  ["W","W"]  ["Slight","Slight"]         0.0      -99999.0
#
#    avgvisft      setprecptyp               time5m  avgchempct  \
# 0    6560.0  ["None","None"]  2018-02-01 00:05:00    -99999.0
# 1    6560.0  ["None","None"]  2018-02-01 00:10:00    -99999.0
# 2    6560.0  ["None","None"]  2018-02-01 00:15:00    -99999.0
# 3    6560.0  ["Snow","Snow"]  2018-02-01 00:20:00    -99999.0
# 4    6000.0  ["Snow","Snow"]  2018-02-01 00:25:00    -99999.0
#
#                            setsurfstat
# 0  ["Trace Moisture","Trace Moisture"]
# 1  ["Trace Moisture","Trace Moisture"]
# 2  ["Trace Moisture","Trace Moisture"]
# 3  ["Trace Moisture","Trace Moisture"]
# 4  ["Trace Moisture","Trace Moisture"]

# %%
VolDat['time5m']=VolDat['DateTime'].astype(str)
RWISdat1['time5m']=RWISdat1['DateTime'].astype(str)
RWISdat1.shape
# Out:
# (38880, 15)

# %%
FinDat1=pd.merge(VolDat,PrimKeyMap, left_on='deviceId', right_on='PrimStat',how='left')

# %%
FinDat2=pd.merge(FinDat1,RWISdat1,left_on=["nearest_rwis","time5m"],right_on=["RWISid","time5m"],how='inner')

# %%
FinDat2.shape
# Out:
# (163296, 32)

# %%
FinDat2 =FinDat2.drop(columns='DateTime_y')
FinDat1.shape
# Out:
# (194400, 18)

# %%
FinDat2 =FinDat2.rename(index=str,columns={'DateTime_x':'DateTime'})
FinDat2 =FinDat2.set_index(['Milepost','DateTime'])
FinDat2=FinDat2.sort_index()
FinDat2.head()
# Out:
#                               deviceId  AvgSpdClass0  AvgSpdClass1  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00       396           0.0     70.780001
#          2018-02-01 00:10:00       396           0.0     58.927500
#          2018-02-01 00:15:00       396           0.0     70.224998
#          2018-02-01 00:20:00       396           0.0     68.897777
#          2018-02-01 00:25:00       396           0.0     64.570000
#
#                               AvgSpdClass2  AvgSpdClass3  VolClass0  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00     61.000000     61.526750          0
#          2018-02-01 00:10:00     72.236666     67.304667          0
#          2018-02-01 00:15:00      0.000000     62.865694          0
#          2018-02-01 00:20:00     64.847499     63.055002          0
#          2018-02-01 00:25:00      0.000000     66.067500          0
#
#                               VolClass1  VolClass2  VolClass3      SITENAME  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00          2          2          9  Laramie East
#          2018-02-01 00:10:00          4          3         15  Laramie East
#          2018-02-01 00:15:00          2          0         13  Laramie East
#          2018-02-01 00:20:00          5          3          6  Laramie East
#          2018-02-01 00:25:00          1          0         11  Laramie East
#
#                                              ...                  avgwindgust  \
# Milepost DateTime                            ...
# 317.68   2018-02-01 00:05:00                 ...                         12.0
#          2018-02-01 00:10:00                 ...                         10.0
#          2018-02-01 00:15:00                 ...                          9.0
#          2018-02-01 00:20:00                 ...                          9.0
#          2018-02-01 00:25:00                 ...                          9.0
#
#                               avgwinddir  setwinddir         setprecpints  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00       254.0   ["W","W"]      ["None","None"]
#          2018-02-01 00:10:00       260.0   ["W","W"]      ["None","None"]
#          2018-02-01 00:15:00       261.0   ["W","W"]      ["None","None"]
#          2018-02-01 00:20:00       256.0   ["W","W"]  ["Slight","Slight"]
#          2018-02-01 00:25:00       250.0   ["W","W"]  ["Slight","Slight"]
#
#                               avgprecprt  avgprecpaccm  avgvisft  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00         0.0      -99999.0    6560.0
#          2018-02-01 00:10:00         0.0      -99999.0    6560.0
#          2018-02-01 00:15:00         0.0      -99999.0    6560.0
#          2018-02-01 00:20:00         0.0      -99999.0    6560.0
#          2018-02-01 00:25:00         0.0      -99999.0    6000.0
#
#                                   setprecptyp  avgchempct  \
# Milepost DateTime
# 317.68   2018-02-01 00:05:00  ["None","None"]    -99999.0
#          2018-02-01 00:10:00  ["None","None"]    -99999.0
#          2018-02-01 00:15:00  ["None","None"]    -99999.0
#          2018-02-01 00:20:00  ["Snow","Snow"]    -99999.0
#          2018-02-01 00:25:00  ["Snow","Snow"]    -99999.0
#
#                                                       setsurfstat
# Milepost DateTime
# 317.68   2018-02-01 00:05:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:10:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:15:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:20:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:25:00  ["Trace Moisture","Trace Moisture"]
#
# [5 rows x 29 columns]

# %%
FinDat2.to_csv('Z:/apoorb/MergeRwisVolDat.csv')

# %%
FinDat2=pd.read_csv('Z:/apoorb/MergeRwisVolDat.csv')

# %%
csv_buffer=StringIO()
FinDat2.to_csv(csv_buffer,sep=",",index=True)
s3=boto3.resource('s3')
s3.Object('prod-sdc-tti-911061262852-us-east-1-bucket','abibeka/Data/MergeRwisVolDat.csv').put(Body=csv_buffer.getvalue())
# Out:
# {u'ETag': '"0acfb9d679a11d793ec44a67b7decdba"',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '0',
#    'date': 'Wed, 17 Apr 2019 15:55:52 GMT',
#    'etag': '"0acfb9d679a11d793ec44a67b7decdba"',
#    'server': 'AmazonS3',
#    'x-amz-id-2': 'vcMYKISKSUI1vg7aIEAqFdx7ZrnQW/UmJ0kY6NAkaYc/XYylH5lVBUP9neM1OfkTlSgjLd+3QDY=',
#    'x-amz-request-id': '378C386DE7B811F7'},
#   'HTTPStatusCode': 200,
#   'HostId': 'vcMYKISKSUI1vg7aIEAqFdx7ZrnQW/UmJ0kY6NAkaYc/XYylH5lVBUP9neM1OfkTlSgjLd+3QDY=',
#   'RequestId': '378C386DE7B811F7',
#   'RetryAttempts': 0}}

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/MergeRwisVolDat.csv')
FinDat2=pd.read_csv(obj['Body'])
FinDat2=FinDat2.drop(columns='Unnamed: 0')
FinDat2.head(200)
# Out:
#      Milepost             DateTime  deviceId  AvgSpdClass0  AvgSpdClass1  \
# 183     74.250000     68.312087          0         24          6
# 184     75.675875     73.182466          0         27         22
# 185     75.847916     68.708213          0         19          8
# 186     76.443000     71.340472          0         31          8
# 187     72.173777     72.327598          0         22         13
# 188     73.173499     71.205349          0         29         19
# 189     69.477082     72.883443          0         36         10
# 190     73.207500     69.959666          0         23         16
# 191     74.372833     71.515202          0         35         14
# 192     68.709999     67.401228          0         24          4
# 193     72.702411     70.484949          0         32         14
# 194     76.369666     70.795671          0         19          9
# 195     75.392223     71.221296          0         24          5
# 196     79.191124     73.680227          0         39         12
# 197     74.367501     71.222821          0         26          8
# 198     74.115833     67.532571          0         33         11
# 199     78.325000     69.785758          0         26          7
#
#                     ...                   avgwindgust avgwinddir   setwinddir  \
# 0                   ...                          12.0      254.0    ["W","W"]
# 1                   ...                          10.0      260.0    ["W","W"]
# 2                   ...                           9.0      261.0    ["W","W"]
# 3                   ...                           9.0      256.0    ["W","W"]
# 4                   ...                           9.0      250.0    ["W","W"]
# 5                   ...                          10.0      244.0  ["SW","SW"]
# 6                   ...                          12.0      247.0  ["SW","SW"]
# 7                   ...                           9.0      240.0  ["SW","SW"]
# 8                   ...                           7.0      236.0  ["SW","SW"]
# 9                   ...                          14.0      234.0  ["SW","SW"]
# 10                  ...                          14.0      229.0  ["SW","SW"]
# 11                  ...                           7.0      237.0  ["SW","SW"]
# 12                  ...                           7.0      241.0  ["SW","SW"]
# 13                  ...                           7.0      243.0  ["SW","SW"]
# 14                  ...                           7.0      251.0    ["W","W"]
# 15                  ...                           7.0      258.0    ["W","W"]
# 16                  ...                           7.0      254.0    ["W","W"]
# 17                  ...                          13.0      256.0    ["W","W"]
# 18                  ...                          13.0      254.0    ["W","W"]
# 19                  ...                          13.0      251.0    ["W","W"]
# 20                  ...                          11.0      250.0    ["W","W"]
# 21                  ...                           7.0      251.0    ["W","W"]
# 22                  ...                           7.0      251.0    ["W","W"]
# 23                  ...                           7.0      250.0    ["W","W"]
# 24                  ...                           8.0      247.0  ["SW","SW"]
# 25                  ...                          10.0      244.0  ["SW","SW"]
# 26                  ...                          10.0      244.0  ["SW","SW"]
# 27                  ...                          12.0      246.0  ["SW","SW"]
# 28                  ...                          12.0      246.0  ["SW","SW"]
# 29                  ...                          12.0      248.0    ["W","W"]
# ..                  ...                           ...        ...          ...
# 170                 ...                          27.0      281.0    ["W","W"]
# 171                 ...                          25.0      282.0    ["W","W"]
# 172                 ...                          25.0      284.0    ["W","W"]
# 173                 ...                          24.0      284.0    ["W","W"]
# 174                 ...                          25.0      282.0    ["W","W"]
# 175                 ...                          25.0      284.0    ["W","W"]
# 176                 ...                          27.0      285.0    ["W","W"]
# 177                 ...                          27.0      284.0    ["W","W"]
# 178                 ...                          25.0      284.0    ["W","W"]
# 179                 ...                          25.0      287.0    ["W","W"]
# 180                 ...                          25.0      287.0    ["W","W"]
# 181                 ...                          24.0      284.0    ["W","W"]
# 182                 ...                          24.0      282.0    ["W","W"]
# 183                 ...                          24.0      282.0    ["W","W"]
# 184                 ...                          22.0      280.0    ["W","W"]
# 185                 ...                          22.0      272.0    ["W","W"]
# 186                 ...                          19.0      277.0    ["W","W"]
# 187                 ...                          21.0      281.0    ["W","W"]
# 188                 ...                          21.0      282.0    ["W","W"]
# 189                 ...                          19.0      285.0    ["W","W"]
# 190                 ...                          20.0      285.0    ["W","W"]
# 191                 ...                          21.0      285.0    ["W","W"]
# 192                 ...                          21.0      285.0    ["W","W"]
# 193                 ...                          19.0      284.0    ["W","W"]
# 194                 ...                          18.0      281.0    ["W","W"]
# 195                 ...                          18.0      280.0    ["W","W"]
# 196                 ...                          17.0      282.0    ["W","W"]
# 197                 ...                          18.0      287.0    ["W","W"]
# 198                 ...                          18.0      285.0    ["W","W"]
# 199                 ...                          17.0      280.0    ["W","W"]
#
#             setprecpints  avgprecprt avgprecpaccm  avgvisft      setprecptyp  \
# 0        ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 1        ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 2        ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 3    ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 4    ["Slight","Slight"]         0.0     -99999.0    6000.0  ["Snow","Snow"]
# 5    ["Slight","Slight"]         0.0     -99999.0    4510.0  ["Snow","Snow"]
# 6    ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 7    ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 8        ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 9        ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 10       ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 11       ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 12       ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 13   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 14   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 15   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 16   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 17   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 18   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 19   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 20               ["",""]         NaN          NaN       NaN          ["",""]
# 21   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 22   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 23   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 24   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 25   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 26   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 27   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 28   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# 29   ["Slight","Slight"]         0.0     -99999.0    6560.0  ["Snow","Snow"]
# ..                   ...         ...          ...       ...              ...
# 170      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 171      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 172      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 173      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 174      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 175      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 176      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 177      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 178      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 179      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 180              ["",""]         NaN          NaN       NaN          ["",""]
# 181      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 182      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 183      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 184      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 185      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 186      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 187      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 188      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 189      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 190      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 191      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 192      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 193      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 194      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 195      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 196      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 197      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 198      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
# 199      ["None","None"]         0.0     -99999.0    6560.0  ["None","None"]
#
#      avgchempct                          setsurfstat
# 0      -99999.0  ["Trace Moisture","Trace Moisture"]
# 1      -99999.0  ["Trace Moisture","Trace Moisture"]
# 2      -99999.0  ["Trace Moisture","Trace Moisture"]
# 3      -99999.0  ["Trace Moisture","Trace Moisture"]
# 4      -99999.0  ["Trace Moisture","Trace Moisture"]
# 5      -99999.0  ["Trace Moisture","Trace Moisture"]
# 6      -99999.0  ["Trace Moisture","Trace Moisture"]
# 7      -99999.0        ["Ice Warning","Ice Warning"]
# 8      -99999.0        ["Ice Warning","Ice Warning"]
# 9      -99999.0        ["Ice Warning","Ice Warning"]
# 10     -99999.0        ["Ice Warning","Ice Warning"]
# 11     -99999.0        ["Ice Warning","Ice Warning"]
# 12     -99999.0        ["Ice Warning","Ice Warning"]
# 13     -99999.0        ["Ice Warning","Ice Warning"]
# 14     -99999.0        ["Ice Warning","Ice Warning"]
# 15     -99999.0        ["Ice Warning","Ice Warning"]
# 16     -99999.0        ["Ice Warning","Ice Warning"]
# 17     -99999.0        ["Ice Warning","Ice Warning"]
# 18     -99999.0        ["Ice Warning","Ice Warning"]
# 19     -99999.0        ["Ice Warning","Ice Warning"]
# 20     -99999.0        ["Ice Warning","Ice Warning"]
# 21     -99999.0        ["Ice Warning","Ice Warning"]
# 22     -99999.0        ["Ice Warning","Ice Warning"]
# 23     -99999.0        ["Ice Warning","Ice Warning"]
# 24     -99999.0        ["Ice Warning","Ice Warning"]
# 25     -99999.0        ["Ice Warning","Ice Warning"]
# 26     -99999.0        ["Ice Warning","Ice Warning"]
# 27     -99999.0        ["Ice Warning","Ice Warning"]
# 28     -99999.0        ["Ice Warning","Ice Warning"]
# 29     -99999.0        ["Ice Warning","Ice Warning"]
# ..          ...                                  ...
# 170    -99999.0                        ["Dry","Dry"]
# 171    -99999.0                        ["Dry","Dry"]
# 172    -99999.0                        ["Dry","Dry"]
# 173    -99999.0                        ["Dry","Dry"]
# 174    -99999.0                        ["Dry","Dry"]
# 175    -99999.0                        ["Dry","Dry"]
# 176    -99999.0                        ["Dry","Dry"]
# 177    -99999.0                        ["Dry","Dry"]
# 178    -99999.0                        ["Dry","Dry"]
# 179    -99999.0                        ["Dry","Dry"]
# 180    -99999.0                        ["Dry","Dry"]
# 181    -99999.0                        ["Dry","Dry"]
# 182    -99999.0                        ["Dry","Dry"]
# 183    -99999.0                        ["Dry","Dry"]
# 184    -99999.0                        ["Dry","Dry"]
# 185    -99999.0                        ["Dry","Dry"]
# 186    -99999.0                        ["Dry","Dry"]
# 187    -99999.0                        ["Dry","Dry"]
# 188    -99999.0                        ["Dry","Dry"]
# 189    -99999.0                        ["Dry","Dry"]
# 190    -99999.0                        ["Dry","Dry"]
# 191    -99999.0                        ["Dry","Dry"]
# 192    -99999.0                        ["Dry","Dry"]
# 193    -99999.0                        ["Dry","Dry"]
# 194    -99999.0                        ["Dry","Dry"]
# 195    -99999.0                        ["Dry","Dry"]
# 196    -99999.0                        ["Dry","Dry"]
# 197    -99999.0                        ["Dry","Dry"]
# 198    -99999.0                        ["Dry","Dry"]
# 199    -99999.0                        ["Dry","Dry"]
#
# [200 rows x 31 columns]

# %%
print(FinDat2.columns)
# Out:
# Index([u'Milepost', u'DateTime', u'deviceId', u'AvgSpdClass0', u'AvgSpdClass1',
#        u'AvgSpdClass2', u'AvgSpdClass3', u'VolClass0', u'VolClass1',
#        u'VolClass2', u'VolClass3', u'SITENAME', u'Direction', u'TotVeh',
#        u'PerHGV', u'time5m', u'PrimStat', u'nearest_rwis', u'RWISid',
#        u'avgairtemp', u'avgwindspd', u'avgwindgust', u'avgwinddir',
#        u'setwinddir', u'setprecpints', u'avgprecprt', u'avgprecpaccm',
#        u'avgvisft', u'setprecptyp', u'avgchempct', u'setsurfstat'],
#       dtype='object')

# %%
R_Nm = {'avgairtemp':'AvgAirTemp','':'','':'','':'','':'','':'','':'','':'','':'','':'','':'','':'','':'','':'','':'',}
