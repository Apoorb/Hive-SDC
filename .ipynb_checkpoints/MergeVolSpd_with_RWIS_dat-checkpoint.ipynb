# %% [markdown]
# # Merge the Volume and Speed Data with the Weather Data

# %% [markdown]
#     Created by: Apoorba Bibeka
#     Date: 04/12/2019

# %%
import boto3 #Need to read and write files to aws s3 bucket
import pandas as pd
from io import BytesIO as StringIO 
import numpy as np

# %% [markdown]
# ## Load the RWIS ATMOS Weather Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018HiveRWIS_AtosDat.csv')
RWISdat=pd.read_csv(obj['Body'])
RWISdat.head()
# Out:
#    rwisid  avgairtemp  avgwindspd  avgwindgust  avgwinddir setwinddir  \
# 0    1354        16.5        11.0         17.0       250.0  ["W","W"]
# 1    1354        16.0         9.0         12.0       254.0  ["W","W"]
# 2    1354        15.3         6.0         10.0       260.0  ["W","W"]
# 3    1354        14.7         6.0          9.0       261.0  ["W","W"]
# 4    1354        14.5         7.0          9.0       256.0  ["W","W"]
#
#           setprecpints  avgprecprt  avgprecpaccm  avgvisft      setprecptyp  \
# 0      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 1      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 2      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 3      ["None","None"]         0.0      -99999.0    6560.0  ["None","None"]
# 4  ["Slight","Slight"]         0.0      -99999.0    6560.0  ["Snow","Snow"]
#
#                 time5m
# 0  2018-02-01 00:00:00
# 1  2018-02-01 00:05:00
# 2  2018-02-01 00:10:00
# 3  2018-02-01 00:15:00
# 4  2018-02-01 00:20:00

# %% [markdown]
# ## Load RWIS Surface Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018HiveRWIS_SurfDat.csv')
Surfdat=pd.read_csv(obj['Body'])
Surfdat.head()
# Out:
#    rwisid  avgchempct                          setsurfstat  \
# 0    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 1    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 2    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 3    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
# 4    1354    -99999.0  ["Trace Moisture","Trace Moisture"]
#
#                 time5m
# 0  2018-02-01 00:00:00
# 1  2018-02-01 00:05:00
# 2  2018-02-01 00:10:00
# 3  2018-02-01 00:15:00
# 4  2018-02-01 00:20:00

# %%
RWISdat1=pd.merge(RWISdat,Surfdat,on=['rwisid','time5m'],how='outer')

# %% [markdown]
# ## Load the Volume Data

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/Feb2018ProcessVolDatClass.csv')
VolDat=pd.read_csv(obj['Body'])
VolDat=VolDat.drop(columns='Unnamed: 0')
VolDat.head()
# Out:
#    deviceId             DateTime  AvgSpdClass0  AvgSpdClass1  AvgSpdClass2  \
# 0       384  2018-02-01 00:05:00           0.0     65.650002     60.340000
# 1       384  2018-02-01 00:10:00           0.0      0.000000     63.280001
# 2       384  2018-02-01 00:15:00           0.0     70.397497     65.567501
# 3       384  2018-02-01 00:20:00           0.0      0.000000     64.876668
# 4       384  2018-02-01 00:25:00           0.0     68.420002      0.000000
#
#    AvgSpdClass3  VolClass0  VolClass1  VolClass2  VolClass3  Milepost  \
# 0     62.452963          0          2          2         16     325.8
# 1     60.666666          0          0          2          7     325.8
# 2     60.180500          0          3          3         11     325.8
# 3     62.102500          0          0          4         13     325.8
# 4     59.529167          0          2          0          8     325.8
#
#   Direction  TotVeh  PerHGV
# 0         I      20   80.00
# 1         I       9   77.78
# 2         I      17   64.71
# 3         I      17   76.47
# 4         I      10   80.00

# %%
VolDat.columns
# Out:
# Index([u'deviceId', u'DateTime', u'AvgSpdClass0', u'AvgSpdClass1',
#        u'AvgSpdClass2', u'AvgSpdClass3', u'VolClass0', u'VolClass1',
#        u'VolClass2', u'VolClass3', u'Milepost', u'Direction', u'TotVeh',
#        u'PerHGV'],
#       dtype='object')

# %% [markdown]
# ## Load the mapping table for Backup Weather Station and speed sensor station

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/SecndRWIS_SpdID_Map.csv')
SecKeyMap=pd.read_csv(obj['Body'])
SecKeyMap.head()
# Out:
#    SecStat  backup_rwis
# 0      383           36
# 1      393         3422
# 2      394           36
# 3      395           36
# 4      396           36

# %% [markdown]
# ## Load the mapping table for Primary Weather Station and speed sensor station

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/PrimRWIS_SpdID_Map.csv')
PrimKeyMap=pd.read_csv(obj['Body'])
PrimKeyMap.head()
# Out:
#    PrimStat  nearest_rwis
# 0       383          1354
# 1       393            36
# 2       394          1354
# 3       395          1354
# 4       396          1354

# %%
# Get index for time 
RWISdat1['DateTime']=pd.to_datetime(RWISdat1['time5m'],format='%Y-%m-%d %H:%M:%S')
dev=RWISdat1.rwisid.unique().tolist()
RWISdat1=RWISdat1.rename(str,columns={'rwisid':'RWISid'})
# Set index
RWISdat1=RWISdat1.set_index(['RWISid','DateTime']) 
# Create time interval index without missing values
index = pd.date_range('2018-02-01','2018-02-28',closed='right',freq='5min')
# Create a multiindex
multi_index=pd.MultiIndex.from_product([dev,index],names=['RWISid','DateTime'])
# Reindex. Now the missing values have nan. 
RWISdat1=RWISdat1.reindex(multi_index)
RWISdat1=RWISdat1.reset_index()

# %%
RWISdat1.head()
# Out:
#    RWISid            DateTime  avgairtemp  avgwindspd  avgwindgust  \
# 0    1354 2018-02-01 00:05:00        16.0         9.0         12.0
# 1    1354 2018-02-01 00:10:00        15.3         6.0         10.0
# 2    1354 2018-02-01 00:15:00        14.7         6.0          9.0
# 3    1354 2018-02-01 00:20:00        14.5         7.0          9.0
# 4    1354 2018-02-01 00:25:00        14.4         6.0          9.0
#
#    avgwinddir setwinddir         setprecpints  avgprecprt  avgprecpaccm  \
# 0       254.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 1       260.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 2       261.0  ["W","W"]      ["None","None"]         0.0      -99999.0
# 3       256.0  ["W","W"]  ["Slight","Slight"]         0.0      -99999.0
# 4       250.0  ["W","W"]  ["Slight","Slight"]         0.0      -99999.0
#
#    avgvisft      setprecptyp               time5m  avgchempct  \
# 0    6560.0  ["None","None"]  2018-02-01 00:05:00    -99999.0
# 1    6560.0  ["None","None"]  2018-02-01 00:10:00    -99999.0
# 2    6560.0  ["None","None"]  2018-02-01 00:15:00    -99999.0
# 3    6560.0  ["Snow","Snow"]  2018-02-01 00:20:00    -99999.0
# 4    6000.0  ["Snow","Snow"]  2018-02-01 00:25:00    -99999.0
#
#                            setsurfstat
# 0  ["Trace Moisture","Trace Moisture"]
# 1  ["Trace Moisture","Trace Moisture"]
# 2  ["Trace Moisture","Trace Moisture"]
# 3  ["Trace Moisture","Trace Moisture"]
# 4  ["Trace Moisture","Trace Moisture"]

# %%
VolDat['time5m']=VolDat['DateTime'].astype(str)
RWISdat1['time5m']=RWISdat1['DateTime'].astype(str)
RWISdat1.shape
# Out:
# (38880, 15)

# %%
FinDat1=pd.merge(VolDat,PrimKeyMap, left_on='deviceId', right_on='PrimStat',how='left')

# %%
FinDat2=pd.merge(FinDat1,RWISdat1,left_on=["nearest_rwis","time5m"],right_on=["RWISid","time5m"],how='inner')

# %%
FinDat2.shape
# Out:
# (38880, 31)

# %%
FinDat2 =FinDat2.drop(columns='DateTime_y')
FinDat1.shape
# Out:
# (38880, 17)

# %%
FinDat2 =FinDat2.rename(index=str,columns={'DateTime_x':'DateTime'})
FinDat2 =FinDat2.set_index(['Milepost','DateTime'])
FinDat2=FinDat2.sort_index()
FinDat2.head()
# Out:
#                               deviceId  AvgSpdClass0  AvgSpdClass1  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00      3654           0.0      0.000000
#          2018-02-01 00:10:00      3654           0.0     57.177501
#          2018-02-01 00:15:00      3654           0.0      0.000000
#          2018-02-01 00:20:00      3654           0.0     65.204998
#          2018-02-01 00:25:00      3654           0.0      0.000000
#
#                               AvgSpdClass2  AvgSpdClass3  VolClass0  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00     56.379999     60.975999          0
#          2018-02-01 00:10:00      0.000000     60.294286          0
#          2018-02-01 00:15:00      0.000000     60.965000          0
#          2018-02-01 00:20:00     64.590000     62.877502          0
#          2018-02-01 00:25:00      0.000000     63.527501          0
#
#                               VolClass1  VolClass2  VolClass3 Direction  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00          0          2          5         D
#          2018-02-01 00:10:00          4          0          7         D
#          2018-02-01 00:15:00          0          0          8         D
#          2018-02-01 00:20:00          4          2          3         D
#          2018-02-01 00:25:00          0          0          4         D
#
#                                              ...                   \
# Milepost DateTime                            ...
# 318.5    2018-02-01 00:05:00                 ...
#          2018-02-01 00:10:00                 ...
#          2018-02-01 00:15:00                 ...
#          2018-02-01 00:20:00                 ...
#          2018-02-01 00:25:00                 ...
#
#                               avgwindgust  avgwinddir setwinddir  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00         12.0       254.0  ["W","W"]
#          2018-02-01 00:10:00         10.0       260.0  ["W","W"]
#          2018-02-01 00:15:00          9.0       261.0  ["W","W"]
#          2018-02-01 00:20:00          9.0       256.0  ["W","W"]
#          2018-02-01 00:25:00          9.0       250.0  ["W","W"]
#
#                                      setprecpints  avgprecprt  avgprecpaccm  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00      ["None","None"]         0.0      -99999.0
#          2018-02-01 00:10:00      ["None","None"]         0.0      -99999.0
#          2018-02-01 00:15:00      ["None","None"]         0.0      -99999.0
#          2018-02-01 00:20:00  ["Slight","Slight"]         0.0      -99999.0
#          2018-02-01 00:25:00  ["Slight","Slight"]         0.0      -99999.0
#
#                               avgvisft      setprecptyp  avgchempct  \
# Milepost DateTime
# 318.5    2018-02-01 00:05:00    6560.0  ["None","None"]    -99999.0
#          2018-02-01 00:10:00    6560.0  ["None","None"]    -99999.0
#          2018-02-01 00:15:00    6560.0  ["None","None"]    -99999.0
#          2018-02-01 00:20:00    6560.0  ["Snow","Snow"]    -99999.0
#          2018-02-01 00:25:00    6000.0  ["Snow","Snow"]    -99999.0
#
#                                                       setsurfstat
# Milepost DateTime
# 318.5    2018-02-01 00:05:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:10:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:15:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:20:00  ["Trace Moisture","Trace Moisture"]
#          2018-02-01 00:25:00  ["Trace Moisture","Trace Moisture"]
#
# [5 rows x 28 columns]

# %%
FinDat2=FinDat2.drop(columns=['time5m'])
R_Nm = {'avgairtemp':'AvgAirTemp','avgwindspd':'AvgWindSpd','avgwindgust':'AvgWindGust',
        'avgwinddir':'AvgWindDir','setwinddir':'ListWindDir','setprecpints':'ListPrecpInts',
        'avgprecprt':'AvgPrecpRt','avgprecpaccm':'AvgPrecpAccm','avgvisft':'AvgVisFt'
        ,'setprecptyp':'ListPrecpTyp','avgchempct':'AvgChemPct','setsurfstat':'ListSurfStat'}
FinDat2=FinDat2.rename(index=str,columns=R_Nm)

# %%
FinDat2.to_csv('Z:/apoorb/MergeRwisVolDat.csv')

# %%
FinDat2=pd.read_csv('Z:/apoorb/MergeRwisVolDat.csv')

# %%
csv_buffer=StringIO()
FinDat2.to_csv(csv_buffer,sep=",",index=True)
s3=boto3.resource('s3')
s3.Object('prod-sdc-tti-911061262852-us-east-1-bucket','abibeka/Data/MergeRwisVolDat.csv').put(Body=csv_buffer.getvalue())

# %%
client=boto3.client('s3')
obj=client.get_object(Bucket='prod-sdc-tti-911061262852-us-east-1-bucket',Key='abibeka/Data/MergeRwisVolDat.csv')
FinDat2=pd.read_csv(obj['Body'])
FinDat2=FinDat2.drop(columns='Unnamed: 0')
FinDat2.head(200)

# %%
print(FinDat2.columns)

# %%
FinDat2.head()
